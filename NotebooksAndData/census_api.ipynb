# %%
# Dependencies
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import seaborn as sns
sns.set(style="darkgrid")
from census import Census
from us import states

# Census API Key 
from config import census_key
c_2013 = Census(census_key)
c_2014 = Census(census_key, year=2014)
c_2015 = Census(census_key, year=2015)
c_2016 = Census(census_key, year=2016)
c_2017 = Census(census_key, year=2017)

# %%
#Get census data for 2013
census_data_2013 = c_2013.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B23025_002E", "B23025_007E", 
                          "C24010_007E", "C24010_008E", "C24010_043E", "C24010_044E", "B01003_001E",
                          "B25035_001E", "B25058_001E", "B25064_001E", "B25077_001E", "B25088_002E",
                          "B15003_017E", "B15003_018E", "B15003_021E", "B15003_022E", "B15003_023E",
                          "B15003_025E"), {'for': 'COUNTY:*'}, year=2013)
census_pd_2013 = pd.DataFrame(census_data_2013)

census_pd_2013 = census_pd_2013.rename(columns={"B19013_001E": "Income",
                                      "B19301_001E": "Income Per Capita",
                                      "B23025_002E": "Employed",
                                      "B23025_007E": "Unemployed",
                                      "C24010_007E": "Employment Male Computer Engineering and Science Occupations",
                                      "C24010_008E": "Employment Male Computer and Mathematical Occupations",
                                      "C24010_043E": "Employment Female Computer Engineering and Science Occupations",
                                      "C24010_044E": "Employment Female Computer and Mathematical Occupations",
                                      "B01003_001E": "Population",
                                      "B25035_001E": "Median House Construction Year",
                                      "B25058_001E": "Average Rent",
                                      "B25064_001E": "Average Cost of Rent plus Utilities",
                                      "B25077_001E": "Average Value of an Owner Occupied Home",
                                      "B25088_002E": "Average Monthly Housing Expense for a Homeowner with a Mortgage",
                                      "B15003_017E": "People with a High School Diploma",
                                      "B15003_018E": "People with a GED",
                                      "B15003_021E": "People with an Associates",
                                      "B15003_022E": "People with a Bachelors",
                                      "B15003_023E": "People with a Masters",
                                      "B15003_025E": "People with a Doctorate",                                  
                                      "NAME": "Name", 
                                      "COUNTY:*": "County"})

# %%
#Get census data for 2014
census_data_2014 = c_2014.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B23025_002E", "B23025_007E", 
                          "C24010_007E", "C24010_008E", "C24010_043E", "C24010_044E", "B01003_001E",
                          "B25035_001E", "B25058_001E", "B25064_001E", "B25077_001E", "B25088_002E",
                          "B15003_017E", "B15003_018E", "B15003_021E", "B15003_022E", "B15003_023E",
                          "B15003_025E"), {'for': 'COUNTY:*'})
census_pd_2014 = pd.DataFrame(census_data_2014)

census_pd_2014 = census_pd_2014.rename(columns={"B19013_001E": "Income",
                                      "B19301_001E": "Income Per Capita",
                                      "B23025_002E": "Employed",
                                      "B23025_007E": "Unemployed",
                                      "C24010_007E": "Employment Male Computer Engineering and Science Occupations",
                                      "C24010_008E": "Employment Male Computer and Mathematical Occupations",
                                      "C24010_043E": "Employment Female Computer Engineering and Science Occupations",
                                      "C24010_044E": "Employment Female Computer and Mathematical Occupations",
                                      "B01003_001E": "Population",
                                      "B25035_001E": "Median House Construction Year",
                                      "B25058_001E": "Average Rent",
                                      "B25064_001E": "Average Cost of Rent plus Utilities",
                                      "B25077_001E": "Average Value of an Owner Occupied Home",
                                      "B25088_002E": "Average Monthly Housing Expense for a Homeowner with a Mortgage",
                                      "B15003_017E": "People with a High School Diploma",
                                      "B15003_018E": "People with a GED",
                                      "B15003_021E": "People with an Associates",
                                      "B15003_022E": "People with a Bachelors",
                                      "B15003_023E": "People with a Masters",
                                      "B15003_025E": "People with a Doctorate",                                  
                                      "NAME": "Name", 
                                      "COUNTY:*": "County"})

# %%
#Get census data for 2015
census_data_2015 = c_2015.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B23025_002E", "B23025_007E", 
                          "C24010_007E", "C24010_008E", "C24010_043E", "C24010_044E", "B01003_001E",
                          "B25035_001E", "B25058_001E", "B25064_001E", "B25077_001E", "B25088_002E",
                          "B15003_017E", "B15003_018E", "B15003_021E", "B15003_022E", "B15003_023E",
                          "B15003_025E"), {'for': 'COUNTY:*'})
census_pd_2015 = pd.DataFrame(census_data_2015)

census_pd_2015 = census_pd_2015.rename(columns={"B19013_001E": "Income",
                                      "B19301_001E": "Income Per Capita",
                                      "B23025_002E": "Employed",
                                      "B23025_007E": "Unemployed",
                                      "C24010_007E": "Employment Male Computer Engineering and Science Occupations",
                                      "C24010_008E": "Employment Male Computer and Mathematical Occupations",
                                      "C24010_043E": "Employment Female Computer Engineering and Science Occupations",
                                      "C24010_044E": "Employment Female Computer and Mathematical Occupations",
                                      "B01003_001E": "Population",
                                      "B25035_001E": "Median House Construction Year",
                                      "B25058_001E": "Average Rent",
                                      "B25064_001E": "Average Cost of Rent plus Utilities",
                                      "B25077_001E": "Average Value of an Owner Occupied Home",
                                      "B25088_002E": "Average Monthly Housing Expense for a Homeowner with a Mortgage",
                                      "B15003_017E": "People with a High School Diploma",
                                      "B15003_018E": "People with a GED",
                                      "B15003_021E": "People with an Associates",
                                      "B15003_022E": "People with a Bachelors",
                                      "B15003_023E": "People with a Masters",
                                      "B15003_025E": "People with a Doctorate",                                  
                                      "NAME": "Name", 
                                      "COUNTY:*": "County"})

# %%
#Get census data for 2016
census_data_2016 = c_2016.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B23025_002E", "B23025_007E", 
                          "C24010_007E", "C24010_008E", "C24010_043E", "C24010_044E", "B01003_001E",
                          "B25035_001E", "B25058_001E", "B25064_001E", "B25077_001E", "B25088_002E",
                          "B15003_017E", "B15003_018E", "B15003_021E", "B15003_022E", "B15003_023E",
                          "B15003_025E"), {'for': 'COUNTY:*'})
census_pd_2016 = pd.DataFrame(census_data_2016)

census_pd_2016 = census_pd_2016.rename(columns={"B19013_001E": "Income",
                                      "B19301_001E": "Income Per Capita",
                                      "B23025_002E": "Employed",
                                      "B23025_007E": "Unemployed",
                                      "C24010_007E": "Employment Male Computer Engineering and Science Occupations",
                                      "C24010_008E": "Employment Male Computer and Mathematical Occupations",
                                      "C24010_043E": "Employment Female Computer Engineering and Science Occupations",
                                      "C24010_044E": "Employment Female Computer and Mathematical Occupations",
                                      "B01003_001E": "Population",
                                      "B25035_001E": "Median House Construction Year",
                                      "B25058_001E": "Average Rent",
                                      "B25064_001E": "Average Cost of Rent plus Utilities",
                                      "B25077_001E": "Average Value of an Owner Occupied Home",
                                      "B25088_002E": "Average Monthly Housing Expense for a Homeowner with a Mortgage",
                                      "B15003_017E": "People with a High School Diploma",
                                      "B15003_018E": "People with a GED",
                                      "B15003_021E": "People with an Associates",
                                      "B15003_022E": "People with a Bachelors",
                                      "B15003_023E": "People with a Masters",
                                      "B15003_025E": "People with a Doctorate",                                  
                                      "NAME": "Name", 
                                      "COUNTY:*": "County"})

# %%
#Get census data for 2017
census_data_2017 = c_2017.acs5.get(("NAME", "B19013_001E", "B19301_001E", "B23025_002E", "B23025_007E", 
                          "C24010_007E", "C24010_008E", "C24010_043E", "C24010_044E", "B01003_001E",
                          "B25035_001E", "B25058_001E", "B25064_001E", "B25077_001E", "B25088_002E",
                          "B15003_017E", "B15003_018E", "B15003_021E", "B15003_022E", "B15003_023E",
                          "B15003_025E"), {'for': 'COUNTY:*'})
census_pd_2017 = pd.DataFrame(census_data_2017)

census_pd_2017 = census_pd_2017.rename(columns={"B19013_001E": "Income",
                                      "B19301_001E": "Income Per Capita",
                                      "B23025_002E": "Employed",
                                      "B23025_007E": "Unemployed",
                                      "C24010_007E": "Employment Male Computer Engineering and Science Occupations",
                                      "C24010_008E": "Employment Male Computer and Mathematical Occupations",
                                      "C24010_043E": "Employment Female Computer Engineering and Science Occupations",
                                      "C24010_044E": "Employment Female Computer and Mathematical Occupations",
                                      "B01003_001E": "Population",
                                      "B25035_001E": "Median House Construction Year",
                                      "B25058_001E": "Average Rent",
                                      "B25064_001E": "Average Cost of Rent plus Utilities",
                                      "B25077_001E": "Average Value of an Owner Occupied Home",
                                      "B25088_002E": "Average Monthly Housing Expense for a Homeowner with a Mortgage",
                                      "B15003_017E": "People with a High School Diploma",
                                      "B15003_018E": "People with a GED",
                                      "B15003_021E": "People with an Associates",
                                      "B15003_022E": "People with a Bachelors",
                                      "B15003_023E": "People with a Masters",
                                      "B15003_025E": "People with a Doctorate",                                  
                                      "NAME": "Name", 
                                      "COUNTY:*": "County"})

# %%
#Breakdown Data for each county in 2013
county_df_2013 = census_pd_2013.groupby(["Name"])  
seattle_county_df_2013 = county_df_2013.get_group("King County, Washington")
portland_county_df_2013 = county_df_2013.get_group("Multnomah County, Oregon")
san_jose_county_df_2013 = county_df_2013.get_group("Santa Clara County, California")
sacramento_county_df_2013 = county_df_2013.get_group("Sacramento County, California")
austin_county_df_2013 = county_df_2013.get_group("Travis County, Texas")
san_antonio_county_df_2013 = county_df_2013.get_group("Bexar County, Texas")

seattle_county_df_2013["Tech City in 2013"] = "Yes"
san_jose_county_df_2013["Tech City in 2013"] = "Yes"
austin_county_df_2013["Tech City in 2013"] = "Yes"
portland_county_df_2013["Tech City in 2013"] = "No"
sacramento_county_df_2013["Tech City in 2013"] = "No"
san_antonio_county_df_2013["Tech City in 2013"] = "No"

#Breakdown Data for each county in 2014
county_df_2014 = census_pd_2014.groupby(["Name"])  
seattle_county_df_2014 = county_df_2014.get_group("King County, Washington")
portland_county_df_2014 = county_df_2014.get_group("Multnomah County, Oregon")
san_jose_county_df_2014 = county_df_2014.get_group("Santa Clara County, California")
sacramento_county_df_2014 = county_df_2014.get_group("Sacramento County, California")
austin_county_df_2014 = county_df_2014.get_group("Travis County, Texas")
san_antonio_county_df_2014 = county_df_2014.get_group("Bexar County, Texas")

seattle_county_df_2014["Tech City in 2014"] = "Yes"
san_jose_county_df_2014["Tech City in 2014"] = "Yes"
austin_county_df_2014["Tech City in 2014"] = "Yes"
portland_county_df_2014["Tech City in 2014"] = "No"
sacramento_county_df_2014["Tech City in 2014"] = "No"
san_antonio_county_df_2014["Tech City in 2014"] = "No"

#Breakdown Data for each county in 2015
county_df_2015 = census_pd_2015.groupby(["Name"])  
seattle_county_df_2015 = county_df_2015.get_group("King County, Washington")
seattle_county_df_2015.set_index("Name")
portland_county_df_2015 = county_df_2015.get_group("Multnomah County, Oregon")
san_jose_county_df_2015 = county_df_2015.get_group("Santa Clara County, California")
sacramento_county_df_2015 = county_df_2015.get_group("Sacramento County, California")
austin_county_df_2015 = county_df_2015.get_group("Travis County, Texas")
san_antonio_county_df_2015 = county_df_2015.get_group("Bexar County, Texas")

seattle_county_df_2015["Tech City in 2015"] = "Yes"
san_jose_county_df_2015["Tech City in 2015"] = "Yes"
austin_county_df_2015["Tech City in 2015"] = "Yes"
portland_county_df_2015["Tech City in 2015"] = "No"
sacramento_county_df_2015["Tech City in 2015"] = "No"
san_antonio_county_df_2015["Tech City in 2015"] = "No"

#Breakdown Data for each county in 2016
county_df_2016 = census_pd_2016.groupby(["Name"])  
seattle_county_df_2016 = county_df_2016.get_group("King County, Washington")
portland_county_df_2016 = county_df_2016.get_group("Multnomah County, Oregon")
san_jose_county_df_2016 = county_df_2016.get_group("Santa Clara County, California")
sacramento_county_df_2016 = county_df_2016.get_group("Sacramento County, California")
austin_county_df_2016 = county_df_2016.get_group("Travis County, Texas")
san_antonio_county_df_2016 = county_df_2016.get_group("Bexar County, Texas")

seattle_county_df_2016["Tech City in 2016"] = "Yes"
san_jose_county_df_2016["Tech City in 2016"] = "Yes"
austin_county_df_2016["Tech City in 2016"] = "Yes"
portland_county_df_2016["Tech City in 2016"] = "No"
sacramento_county_df_2016["Tech City in 2016"] = "No"
san_antonio_county_df_2016["Tech City in 2016"] = "No"

#Breakdown Data for each county in 2017
county_df_2017 = census_pd_2017.groupby(["Name"])  
seattle_county_df_2017 = county_df_2017.get_group("King County, Washington")
portland_county_df_2017 = county_df_2017.get_group("Multnomah County, Oregon")
san_jose_county_df_2017 = county_df_2017.get_group("Santa Clara County, California")
sacramento_county_df_2017 = county_df_2017.get_group("Sacramento County, California")
austin_county_df_2017 = county_df_2017.get_group("Travis County, Texas")
san_antonio_county_df_2017 = county_df_2017.get_group("Bexar County, Texas")

seattle_county_df_2017["Tech City in 2017"] = "Yes"
san_jose_county_df_2017["Tech City in 2017"] = "Yes"
austin_county_df_2017["Tech City in 2017"] = "Yes"
portland_county_df_2017["Tech City in 2017"] = "No"
sacramento_county_df_2017["Tech City in 2017"] = "No"
san_antonio_county_df_2017["Tech City in 2017"] = "No"

# %%
#Merge county data frames for 2013
county_frames_13 = [seattle_county_df_2013, portland_county_df_2013, san_jose_county_df_2013, sacramento_county_df_2013,
                austin_county_df_2013, san_antonio_county_df_2013]
county_frames_df_2013 = pd.concat(county_frames_13)
county_frames_df_2013.to_csv("../Output/county_data_2013.csv", encoding="utf-8", index=True)
county_frames_df_2013 = county_frames_df_2013.set_index("Name")

# %%
employment_2013 = county_frames_df_2013.loc[["King County, Washington", "Multnomah County, Oregon", "Santa Clara County, California",
                          "Sacramento County, California", "Travis County, Texas", "Bexar County, Texas"], 
                          ["Population", "Employed", "Employment Male Computer Engineering and Science Occupations",
                          "Employment Male Computer and Mathematical Occupations", "Employment Female Computer Engineering and Science Occupations",
                          "Employment Female Computer and Mathematical Occupations", "Tech City in 2013"]]
employment_2013["Tech Jobs"] = employment_2013["Employment Male Computer Engineering and Science Occupations"]+employment_2013["Employment Male Computer and Mathematical Occupations"]
+employment_2013["Employment Female Computer Engineering and Science Occupations"]+employment_2013["Employment Female Computer and Mathematical Occupations"]
employment_2013["Non Tech Jobs"]= employment_2013["Employed"]-employment_2013["Tech Jobs"]
tech_2013 = sns.lmplot(x="Population", y="Employed", hue="Tech City in 2013",
               truncate=True, height=6, data=employment_2013)
ax = plt.gca()
ax.set_title("Employment in 2013")

tech_2013.savefig("../Output/Employment_2013.png")

# %%
#Merge county data frames for 2014
county_frames_14 = [seattle_county_df_2014, portland_county_df_2014, san_jose_county_df_2014, sacramento_county_df_2014,
                austin_county_df_2014, san_antonio_county_df_2014]
county_frames_df_2014 = pd.concat(county_frames_14)
county_frames_df_2014.to_csv("../Output/county_data_2014.csv", encoding="utf-8", index=True)
county_frames_df_2014 = county_frames_df_2014.set_index("Name")

# %%
employment_2014 = county_frames_df_2014.loc[["King County, Washington", "Multnomah County, Oregon", "Santa Clara County, California",
                          "Sacramento County, California", "Travis County, Texas", "Bexar County, Texas"], 
                          ["Population", "Employed", "Employment Male Computer Engineering and Science Occupations",
                          "Employment Male Computer and Mathematical Occupations", "Employment Female Computer Engineering and Science Occupations",
                          "Employment Female Computer and Mathematical Occupations", "Tech City in 2014"]]
employment_2014["Tech Jobs"] = employment_2014["Employment Male Computer Engineering and Science Occupations"]+employment_2014["Employment Male Computer and Mathematical Occupations"]
+employment_2014["Employment Female Computer Engineering and Science Occupations"]+employment_2014["Employment Female Computer and Mathematical Occupations"]
employment_2014["Non Tech Jobs"]= employment_2014["Employed"]-employment_2014["Tech Jobs"]
tech_2014 = sns.lmplot(x="Population", y="Employed", hue="Tech City in 2014",
               truncate=True, height=6, data=employment_2014)
ax = plt.gca()
ax.set_title("Employment in 2014")
tech_2014.savefig("../Output/Employment_2014.png")

# %%
#Merge county data frames for 2015
county_frames_15 = [seattle_county_df_2015, portland_county_df_2015, san_jose_county_df_2015, sacramento_county_df_2015,
                austin_county_df_2015, san_antonio_county_df_2015]
county_frames_df_2015 = pd.concat(county_frames_15)
county_frames_df_2015.to_csv("../Output/county_data_2015.csv", encoding="utf-8", index=True)
county_frames_df_2015 = county_frames_df_2015.set_index("Name")

# %%
# Focus on columns involving employment
employment_2015 = county_frames_df_2015.loc[["King County, Washington", "Multnomah County, Oregon", "Santa Clara County, California",
                          "Sacramento County, California", "Travis County, Texas", "Bexar County, Texas"], 
                          ["Population", "Employed", "Employment Male Computer Engineering and Science Occupations",
                          "Employment Male Computer and Mathematical Occupations", "Employment Female Computer Engineering and Science Occupations",
                          "Employment Female Computer and Mathematical Occupations", "Tech City in 2015"]]
employment_2015["Tech Jobs"] = employment_2015["Employment Male Computer Engineering and Science Occupations"]+employment_2015["Employment Male Computer and Mathematical Occupations"]
+employment_2015["Employment Female Computer Engineering and Science Occupations"]+employment_2015["Employment Female Computer and Mathematical Occupations"]
employment_2015["Non Tech Jobs"]= employment_2015["Employed"]-employment_2015["Tech Jobs"]
tech_2015 = sns.lmplot(x="Population", y="Employed", hue="Tech City in 2015",
               truncate=True, height=6, data=employment_2015)
ax = plt.gca()
ax.set_title("Employment in 2015")
tech_2015.savefig("../Output/Employment_2015.png")

# %%
#Merge county data frames for 2016
county_frames_16 = [seattle_county_df_2016, portland_county_df_2016, san_jose_county_df_2016, sacramento_county_df_2016,
                austin_county_df_2016, san_antonio_county_df_2016]
county_frames_df_2016 = pd.concat(county_frames_16)
county_frames_df_2016.to_csv("../Output/county_data_2016.csv", encoding="utf-8", index=True)
county_frames_df_2016 = county_frames_df_2016.set_index("Name")

# %%
employment_2016 = county_frames_df_2016.loc[["King County, Washington", "Multnomah County, Oregon", "Santa Clara County, California",
                          "Sacramento County, California", "Travis County, Texas", "Bexar County, Texas"], 
                          ["Population", "Employed", "Employment Male Computer Engineering and Science Occupations",
                          "Employment Male Computer and Mathematical Occupations", "Employment Female Computer Engineering and Science Occupations",
                          "Employment Female Computer and Mathematical Occupations", "Tech City in 2016"]]
employment_2016["Tech Jobs"] = employment_2016["Employment Male Computer Engineering and Science Occupations"]+employment_2016["Employment Male Computer and Mathematical Occupations"]
+employment_2016["Employment Female Computer Engineering and Science Occupations"]+employment_2016["Employment Female Computer and Mathematical Occupations"]
employment_2016["Non Tech Jobs"]= employment_2016["Employed"]-employment_2016["Tech Jobs"]
tech_2016 = sns.lmplot(x="Population", y="Employed", hue="Tech City in 2016",
               truncate=True, height=6, data=employment_2016)
ax = plt.gca()
ax.set_title("Employment in 2016")
tech_2016.savefig("../Output/Employment_2016.png")

# %%
#Merge county data frames for 2017
county_frames_17 = [seattle_county_df_2017, portland_county_df_2017, san_jose_county_df_2017, sacramento_county_df_2017,
                austin_county_df_2017, san_antonio_county_df_2017]
county_frames_df_2017 = pd.concat(county_frames_17)
county_frames_df_2017.to_csv("../Output/county_data_2017.csv", encoding="utf-8", index=True)
county_frames_df_2017 = county_frames_df_2017.set_index("Name")

# %%
employment_2017 = county_frames_df_2017.loc[["King County, Washington", "Multnomah County, Oregon", "Santa Clara County, California",
                          "Sacramento County, California", "Travis County, Texas", "Bexar County, Texas"], 
                          ["Population", "Employed", "Employment Male Computer Engineering and Science Occupations",
                          "Employment Male Computer and Mathematical Occupations", "Employment Female Computer Engineering and Science Occupations",
                          "Employment Female Computer and Mathematical Occupations", "Tech City in 2017"]]
employment_2017["Tech Jobs"] = employment_2017["Employment Male Computer Engineering and Science Occupations"]+employment_2017["Employment Male Computer and Mathematical Occupations"]
+employment_2017["Employment Female Computer Engineering and Science Occupations"]+employment_2017["Employment Female Computer and Mathematical Occupations"]
employment_2017["Non Tech Jobs"]= employment_2017["Employed"]-employment_2017["Tech Jobs"]
tech_2017 = sns.lmplot(x="Population", y="Employed", hue="Tech City in 2017",
               truncate=True, height=6, data=employment_2017)
ax = plt.gca()
ax.set_title("Employment in 2017")
tech_2017.savefig("../Output/Employment_2017.png")

# %%
merged_census = pd.merge(county_frames_df_2013,county_frames_df_2014, on='Name', how='outer', suffixes=('_2013', '_2014'))
merged_census1 = pd.merge(county_frames_df_2015,county_frames_df_2016, on='Name', how='outer', suffixes=('_2015', '_2016'))
merged_census2 = pd.merge(merged_census,merged_census1, on='Name', how='outer')
merged_census3 = pd.merge(merged_census2,county_frames_df_2017, on='Name', how='outer')
merged_census3
# Out:
#                                 Population_2013  \
# Name
# King County, Washington               1974567.0
# Multnomah County, Oregon               747641.0
# Santa Clara County, California        1812208.0
# Sacramento County, California         1435207.0
# Travis County, Texas                  1063248.0
# Bexar County, Texas                   1753238.0
#
#                                 People with a High School Diploma_2013  \
# Name
# King County, Washington                                       199692.0
# Multnomah County, Oregon                                       82460.0
# Santa Clara County, California                                169834.0
# Sacramento County, California                                 176751.0
# Travis County, Texas                                           96045.0
# Bexar County, Texas                                           220020.0
#
#                                 People with a GED_2013  \
# Name
# ...

# %%
merged_census3["People_with_College_Degrees_2013"] = merged_census3["People with an Associates_2013"]+merged_census3["People with a Bachelors_2013"]+merged_census3["People with a Masters_2013"]+merged_census3["People with a Doctorate_2013"]
merged_census3["People_with_College_Degrees_2014"] = merged_census3["People with an Associates_2014"]+merged_census3["People with a Bachelors_2014"]+merged_census3["People with a Masters_2014"]+merged_census3["People with a Doctorate_2014"]
merged_census3["People_with_College_Degrees_2015"] = merged_census3["People with an Associates_2015"]+merged_census3["People with a Bachelors_2015"]+merged_census3["People with a Masters_2015"]+merged_census3["People with a Doctorate_2015"]
merged_census3["People_with_College_Degrees_2016"] = merged_census3["People with an Associates_2016"]+merged_census3["People with a Bachelors_2016"]+merged_census3["People with a Masters_2016"]+merged_census3["People with a Doctorate_2016"]
merged_census3["People_with_College_Degrees_2017"] = merged_census3["People with an Associates"]+merged_census3["People with a Bachelors"]+merged_census3["People with a Masters"]+merged_census3["People with a Doctorate"]
merged_census3
# Out:
#                                 Population_2013  \
# Name
# King County, Washington               1974567.0
# Multnomah County, Oregon               747641.0
# Santa Clara County, California        1812208.0
# Sacramento County, California         1435207.0
# Travis County, Texas                  1063248.0
# Bexar County, Texas                   1753238.0
#
#                                 People with a High School Diploma_2013  \
# Name
# King County, Washington                                       199692.0
# Multnomah County, Oregon                                       82460.0
# Santa Clara County, California                                169834.0
# Sacramento County, California                                 176751.0
# Travis County, Texas                                           96045.0
# Bexar County, Texas                                           220020.0
#
#                                 People with a GED_2013  \
# Name
# ...

# %%
education_df = merged_census3[["Population_2013", "People_with_College_Degrees_2013", "Population_2014", "People_with_College_Degrees_2014", "Population_2015"
                               ,"People_with_College_Degrees_2015", "Population_2016", "People_with_College_Degrees_2016", 
                               "Population", "People_with_College_Degrees_2017"]]
education_df["Tech City"] = ["Yes","No","Yes","No","Yes","No"]
education_df = education_df.rename(columns={"Population": "Population_2017"})
education_df["% of Population with College Degrees_2013"]= education_df["People_with_College_Degrees_2013"]/education_df["Population_2013"]*100
education_df["% of Population with College Degrees_2014"]= education_df["People_with_College_Degrees_2014"]/education_df["Population_2014"]*100
education_df["% of Population with College Degrees_2015"]= education_df["People_with_College_Degrees_2015"]/education_df["Population_2015"]*100
education_df["% of Population with College Degrees_2016"]= education_df["People_with_College_Degrees_2016"]/education_df["Population_2016"]*100
education_df["% of Population with College Degrees_2017"]= education_df["People_with_College_Degrees_2017"]/education_df["Population_2017"]*100

education_df
# Out:
#                                 Population_2013  \
# Name
# King County, Washington               1974567.0
# Multnomah County, Oregon               747641.0
# Santa Clara County, California        1812208.0
# Sacramento County, California         1435207.0
# Travis County, Texas                  1063248.0
# Bexar County, Texas                   1753238.0
#
#                                 People_with_College_Degrees_2013  \
# Name
# King County, Washington                                 708197.0
# Multnomah County, Oregon                                228850.0
# Santa Clara County, California                          621508.0
# Sacramento County, California                           326434.0
# Travis County, Texas                                    327149.0
# Bexar County, Texas                                     345784.0
#
#                                 Population_2014  \
# Name
# King County, Washington               2008997.0
# ...

# %%
x_axis = [education_df["Population_2013"], education_df["Population_2014"],education_df["Population_2015"],
          education_df["Population_2016"], education_df["Population_2017"]]
y_axis = [education_df["People_with_College_Degrees_2013"], education_df["People_with_College_Degrees_2014"]
         , education_df["People_with_College_Degrees_2015"], education_df["People_with_College_Degrees_2016"]
         , education_df["People_with_College_Degrees_2017"]]
plt.scatter(x_axis[0], y_axis[0], marker="o", color="red")
plt.scatter(x_axis[1], y_axis[1], marker="o", color="green")
plt.scatter(x_axis[2], y_axis[2], marker="o", color="blue")
plt.scatter(x_axis[3], y_axis[3], marker="o", color="yellow")
plt.scatter(x_axis[4], y_axis[4], marker="o", color="orange")
plt.show()

# %%
education_df_transposed = education_df.T 
education_df_transposed
# Out:
# Name                                      King County, Washington  \
# Population_2013                                       1.97457e+06
# People_with_College_Degrees_2013                           708197
# Population_2014                                         2.009e+06
# People_with_College_Degrees_2014                           732497
# Population_2015                                       2.04576e+06
# People_with_College_Degrees_2015                           760019
# Population_2016                                       2.07955e+06
# People_with_College_Degrees_2016                           791123
# Population_2017                                       2.11812e+06
# People_with_College_Degrees_2017                           827017
# Tech City                                                     Yes
# % of Population with College Degrees_2013                 35.8659
# % of Population with College Degrees_2014                 36.4608
# ...

# %%
king_county_x_edu = [education_df_transposed["King County, Washington"]["Population_2013"], education_df_transposed["King County, Washington"]["Population_2014"],
                     education_df_transposed["King County, Washington"]["Population_2015"], education_df_transposed["King County, Washington"]["Population_2016"],
                     education_df_transposed["King County, Washington"]["Population_2017"]]
santa_clara_county_x_edu = [education_df_transposed["Santa Clara County, California"]["Population_2013"], education_df_transposed["Santa Clara County, California"]["Population_2014"],
                            education_df_transposed["Santa Clara County, California"]["Population_2015"], education_df_transposed["Santa Clara County, California"]["Population_2016"],
                            education_df_transposed["Santa Clara County, California"]["Population_2017"]]
travis_county_x_edu = [education_df_transposed["Travis County, Texas"]["Population_2013"], education_df_transposed["Travis County, Texas"]["Population_2014"],
                       education_df_transposed["Travis County, Texas"]["Population_2015"], education_df_transposed["Travis County, Texas"]["Population_2016"],
                       education_df_transposed["Travis County, Texas"]["Population_2017"]]
king_county_y_edu = [education_df_transposed["King County, Washington"]["People_with_College_Degrees_2013"], education_df_transposed["King County, Washington"]["People_with_College_Degrees_2014"],
                     education_df_transposed["King County, Washington"]["People_with_College_Degrees_2015"], education_df_transposed["King County, Washington"]["People_with_College_Degrees_2016"],
                     education_df_transposed["King County, Washington"]["People_with_College_Degrees_2017"]]
santa_clara_y_edu = [education_df_transposed["Santa Clara County, California"]["People_with_College_Degrees_2013"], education_df_transposed["Santa Clara County, California"]["People_with_College_Degrees_2014"],
                     education_df_transposed["Santa Clara County, California"]["People_with_College_Degrees_2015"], education_df_transposed["Santa Clara County, California"]["People_with_College_Degrees_2016"],
                     education_df_transposed["Santa Clara County, California"]["People_with_College_Degrees_2017"]]
travis_county_y_edu = [education_df_transposed["Travis County, Texas"]["People_with_College_Degrees_2013"], education_df_transposed["Travis County, Texas"]["People_with_College_Degrees_2014"],
                       education_df_transposed["Travis County, Texas"]["People_with_College_Degrees_2015"], education_df_transposed["Travis County, Texas"]["People_with_College_Degrees_2016"],
                       education_df_transposed["Travis County, Texas"]["People_with_College_Degrees_2017"]]
multnomah_county_x_edu = [education_df_transposed["Multnomah County, Oregon"]["Population_2013"], education_df_transposed["Multnomah County, Oregon"]["Population_2014"],
                          education_df_transposed["Multnomah County, Oregon"]["Population_2015"], education_df_transposed["Multnomah County, Oregon"]["Population_2016"],
                          education_df_transposed["Multnomah County, Oregon"]["Population_2017"]]
sacramento_county_x_edu = [education_df_transposed["Sacramento County, California"]["Population_2013"], education_df_transposed["Sacramento County, California"]["Population_2014"],
                            education_df_transposed["Sacramento County, California"]["Population_2015"], education_df_transposed["Sacramento County, California"]["Population_2016"],
                            education_df_transposed["Sacramento County, California"]["Population_2017"]]
bexar_county_x_edu = [education_df_transposed["Bexar County, Texas"]["Population_2013"], education_df_transposed["Bexar County, Texas"]["Population_2014"],
                       education_df_transposed["Bexar County, Texas"]["Population_2015"], education_df_transposed["Bexar County, Texas"]["Population_2016"],
                       education_df_transposed["Bexar County, Texas"]["Population_2017"]]
multnomah_county_y_edu = [education_df_transposed["Multnomah County, Oregon"]["People_with_College_Degrees_2013"], education_df_transposed["Multnomah County, Oregon"]["People_with_College_Degrees_2014"],
                          education_df_transposed["Multnomah County, Oregon"]["People_with_College_Degrees_2015"], education_df_transposed["Multnomah County, Oregon"]["People_with_College_Degrees_2016"],
                          education_df_transposed["Multnomah County, Oregon"]["People_with_College_Degrees_2017"]]
sacramento_y_edu = [education_df_transposed["Sacramento County, California"]["People_with_College_Degrees_2013"], education_df_transposed["Sacramento County, California"]["People_with_College_Degrees_2014"],
                     education_df_transposed["Sacramento County, California"]["People_with_College_Degrees_2015"], education_df_transposed["Sacramento County, California"]["People_with_College_Degrees_2016"],
                     education_df_transposed["Sacramento County, California"]["People_with_College_Degrees_2017"]]
bexar_county_y_edu = [education_df_transposed["Bexar County, Texas"]["People_with_College_Degrees_2013"], education_df_transposed["Bexar County, Texas"]["People_with_College_Degrees_2014"],
                       education_df_transposed["Bexar County, Texas"]["People_with_College_Degrees_2015"], education_df_transposed["Bexar County, Texas"]["People_with_College_Degrees_2016"],
                       education_df_transposed["Bexar County, Texas"]["People_with_College_Degrees_2017"]]

# %%
plt.title("People with College Degree vs Population(2013-2017)")
plt.xlabel("Population")
plt.ylabel("People with College Degree(s)")
plt.scatter(king_county_x_edu, king_county_y_edu, marker="o", color="red")
plt.scatter(santa_clara_county_x_edu, santa_clara_y_edu, marker="o", color="green")
plt.scatter(travis_county_x_edu, travis_county_y_edu, marker="o", color="blue")
plt.scatter(multnomah_county_x_edu, multnomah_county_y_edu, marker="o", color="lightcoral")
plt.scatter(sacramento_county_x_edu, sacramento_y_edu, marker="o", color="springgreen")
plt.scatter(bexar_county_x_edu, bexar_county_y_edu, marker="o", color="lightskyblue")
plt.show()

# %%
king_county_y_perc = [education_df_transposed["King County, Washington"]["% of Population with College Degrees_2013"], education_df_transposed["King County, Washington"]["% of Population with College Degrees_2014"],
                     education_df_transposed["King County, Washington"]["% of Population with College Degrees_2015"], education_df_transposed["King County, Washington"]["% of Population with College Degrees_2016"],
                     education_df_transposed["King County, Washington"]["% of Population with College Degrees_2017"]]
santa_clara_y_perc = [education_df_transposed["Santa Clara County, California"]["% of Population with College Degrees_2013"], education_df_transposed["Santa Clara County, California"]["% of Population with College Degrees_2014"],
                     education_df_transposed["Santa Clara County, California"]["% of Population with College Degrees_2015"], education_df_transposed["Santa Clara County, California"]["% of Population with College Degrees_2016"],
                     education_df_transposed["Santa Clara County, California"]["% of Population with College Degrees_2017"]]
travis_county_y_perc = [education_df_transposed["Travis County, Texas"]["% of Population with College Degrees_2013"], education_df_transposed["Travis County, Texas"]["% of Population with College Degrees_2014"],
                       education_df_transposed["Travis County, Texas"]["% of Population with College Degrees_2015"], education_df_transposed["Travis County, Texas"]["% of Population with College Degrees_2016"],
                       education_df_transposed["Travis County, Texas"]["% of Population with College Degrees_2017"]]
multnomah_county_y_perc = [education_df_transposed["Multnomah County, Oregon"]["% of Population with College Degrees_2013"], education_df_transposed["Multnomah County, Oregon"]["% of Population with College Degrees_2014"],
                          education_df_transposed["Multnomah County, Oregon"]["% of Population with College Degrees_2015"], education_df_transposed["Multnomah County, Oregon"]["% of Population with College Degrees_2016"],
                          education_df_transposed["Multnomah County, Oregon"]["% of Population with College Degrees_2017"]]
sacramento_y_perc = [education_df_transposed["Sacramento County, California"]["% of Population with College Degrees_2013"], education_df_transposed["Sacramento County, California"]["% of Population with College Degrees_2014"],
                     education_df_transposed["Sacramento County, California"]["% of Population with College Degrees_2015"], education_df_transposed["Sacramento County, California"]["% of Population with College Degrees_2016"],
                     education_df_transposed["Sacramento County, California"]["% of Population with College Degrees_2017"]]
bexar_county_y_perc = [education_df_transposed["Bexar County, Texas"]["% of Population with College Degrees_2013"], education_df_transposed["Bexar County, Texas"]["% of Population with College Degrees_2014"],
                       education_df_transposed["Bexar County, Texas"]["% of Population with College Degrees_2015"], education_df_transposed["Bexar County, Texas"]["% of Population with College Degrees_2016"],
                       education_df_transposed["Bexar County, Texas"]["% of Population with College Degrees_2017"]]

# %%
plt.title("% of Population with College Degree vs Population(2013-2017)")
plt.xlabel("Population")
plt.ylabel("% of Population with College Degree(s)")
plt.scatter(king_county_x_edu, king_county_y_perc, marker="o", color="red")
plt.scatter(santa_clara_county_x_edu, santa_clara_y_perc, marker="o", color="green")
plt.scatter(travis_county_x_edu, travis_county_y_perc, marker="o", color="blue")
plt.scatter(multnomah_county_x_edu, multnomah_county_y_perc, marker="o", color="lightcoral")
plt.scatter(sacramento_county_x_edu, sacramento_y_perc, marker="o", color="springgreen")
plt.scatter(bexar_county_x_edu, bexar_county_y_perc, marker="o", color="lightskyblue")
plt.show()

# %%
perc_edu = sns.lmplot(x="Population_2013", y="% of Population with College Degrees_2013", hue="Tech City",
               truncate=True, height=5, data=education_df)

# %%
pop_2013 = sns.FacetGrid(education_df, col="Tech City")
pop_2013 = pop_2013.map(plt.scatter, "Population_2013", "% of Population with College Degrees_2013", color="m")
tech_2017.savefig("../Output/Education_2013.png")

# %%
pop_2017 = sns.FacetGrid(education_df, col="Tech City")
pop_2017 = pop_2017.map(plt.scatter, "Population_2017", "% of Population with College Degrees_2017", color="m")
tech_2017.savefig("../Output/Education_2017.png")
